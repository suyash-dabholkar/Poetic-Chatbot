# %% [markdown]
# **INSTALLING PACKAGES**

# %%
# !pip install transformers diffusers accelerate safetensors
# !pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 38.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 24.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 211.5/211.5 MB 160.8 MB/s eta 0:00:01

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
from diffusers import StableDiffusionPipeline
import torch
from PIL import Image
import os

# %% [markdown]
# **LOADING THE DIFFUSION MODEL**

# %%
pipe = StableDiffusionPipeline.from_pretrained(
   "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16,
)
pipe = pipe.to("cuda"if torch.cuda.is_available() else "cpu")

# %% [markdown]
# **GIVING TEXT PROMPT**

# %%
num_prompts = int(input("kitne photo chahiye re ?"))
prompts =[]
for i in range(num_prompts):
  prompt = input(f"enter the prompt #{i+1}:")
  prompts.append(prompt)

# %% [markdown]
# **CREATING OUTPUT DIRECTORY**

# %%
os.makedirs("generated_images", exist_ok=True)

# %% [markdown]
# **GENERATE AND SAVE IMAGES**

# %%
for idx, prompt in enumerate(prompts):
  print(f"Generating Image for: {prompt}")
  image = pipe(prompt).images[0]
  image_path = f"generated_images/image_{idx+1}.png"
  image.save(image_path)
  print(f"Saved: {image_path}")

print("All Images generated succesfully")
